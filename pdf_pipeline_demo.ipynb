# %% [markdown]
# # PDF Pipeline Demo
#
# Notebook de test du pipeline.

# %%
from main import df
df.head()
# Out:
#    page  width  height  page_area  image_ratio  image_count  text_ratio  \
# 0     1  612.0   792.0   484704.0          1.0            1    0.012739
# 1     2  612.0   792.0   484704.0          1.0            1    0.012203
# 2     3  612.0   792.0   484704.0          1.0            1    0.011784
# 3     4  612.0   792.0   484704.0          1.0            1    0.012739
# 4     5  612.0   792.0   484704.0          1.0            1    0.012203
#
#    block_count   density  native_chars  native_words  native_score  \
# 0            9  0.000019           332            46      0.791519
# 1            9  0.000019           320            44      0.805148
# 2            9  0.000019           305            41      0.815856
# 3            9  0.000019           332            46      0.791519
# 4            9  0.000019           320            44      0.805148
#
#    repetition_score page_type  processing_time  qa_valid qa_flags  \
# ...

# %%
df[['page', 'page_type', 'image_ratio', 'text_ratio']]
# Out:
#     page page_type  image_ratio  text_ratio
# 0      1      scan          1.0    0.012739
# 1      2      scan          1.0    0.012203
# 2      3      scan          1.0    0.011784
# 3      4      scan          1.0    0.012739
# 4      5      scan          1.0    0.012203
# 5      6      scan          1.0    0.011784
# 6      7      scan          1.0    0.012739
# 7      8      scan          1.0    0.012203
# 8      9      scan          1.0    0.011784
# 9     10      scan          1.0    0.012739
# 10    11      scan          1.0    0.012203
# 11    12      scan          1.0    0.011784
# 12    13      scan          1.0    0.012739
# 13    14      scan          1.0    0.012203
# 14    15      scan          1.0    0.011784
# 15    16      scan          1.0    0.012739
# 16    17      scan          1.0    0.012203
# 17    18      scan          1.0    0.011784
# 18    19      scan          1.0    0.012739
# 19    20      scan          1.0    0.012203
# ...

# %%
df[df['qa_valid'] == False]
# Out:
# Empty DataFrame
# Columns: [page, width, height, page_area, image_ratio, image_count, text_ratio, block_count, density, native_chars, native_words, native_score, repetition_score, page_type, processing_time, qa_valid, qa_flags, text]
# Index: []
